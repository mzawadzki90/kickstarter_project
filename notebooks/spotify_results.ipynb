# %%
# modules we'll use
import pandas as pd
from textwrap import wrap
import matplotlib.pyplot as plt

# %%
# read in all our data
spotify_results = pd.read_csv("../results/genetic_algorithm_stats_2022-01-14_19-31-13.csv")

# %%
# look at a few rows of the results file
spotify_results.sample(5)
# Out:
#      Generation number  Best fitness  \
# 142                142    107.451050
# 118                118    107.451050
# 22                  22    107.928436
# 94                  94    107.451050
# 36                  36    107.798042
#
#                                            Best genome  Worst fitness  \
# 142  Genome{fitness:107.4510498046875,genes:[Intege...     115.495293
# 118  Genome{fitness:107.4510498046875,genes:[Intege...     109.857277
# 22   Genome{fitness:107.92843627929688,genes:[Integ...     109.509071
# 94   Genome{fitness:107.4510498046875,genes:[Intege...     108.714760
# 36   Genome{fitness:107.79804229736328,genes:[Integ...     110.250618
#
#                                           Worst genome        Mean  \
# 142  Genome{fitness:115.49529266357422,genes:[Integ...  108.302995
# 118  Genome{fitness:109.8572769165039,genes:[Intege...  107.823228
# 22   Genome{fitness:109.50907135009766,genes:[Integ...  108.265331
# 94   Genome{fitness:108.71475982666016,genes:[Integ...  107.774811
# 36   Genome{fitness:110.25061798095703,genes:[Integ...  108.144962
#
#         Average  Standard deviation
# 142  108.302995            1.895644
# 118  107.823228            0.528489
# 22   108.265331            0.333599
# 94   107.774811            0.329594
# 36   108.144962            0.504600

# %%
# get info about DataFrame columns
spotify_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Generation number   201 non-null    int64
#  1   Best fitness        201 non-null    float64
#  2   Best genome         201 non-null    object
#  3   Worst fitness       201 non-null    float64
#  4   Worst genome        201 non-null    object
#  5   Mean                201 non-null    float64
#  6   Average             201 non-null    float64
#  7   Standard deviation  201 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 12.7+ KB

# %%
ax = spotify_results.plot(x='Generation number', y='Best fitness', title='Dopasowanie najlepszego osobnika w populacji',
                          grid=True, legend=False)
ax.set_xlabel('Numer pokolenia')
ax.set_ylabel('Wartość funkcji dopasowania (MSE walid.)')
plt.savefig('plots\\g_a_best_fitness.eps')

# %%
ax = spotify_results.plot(x='Generation number', y='Worst fitness',
                          title='Dopasowanie najgorszego osobnika w populacji', grid=True, legend=False)
ax.set_xlabel('Numer pokolenia')
ax.set_ylabel('\n'.join(wrap('Wartość funkcji dopasowania (MSE walidacyjne)', 30)))
plt.savefig('plots\\g_a_worst_fitness.eps')

# %%
ax = spotify_results.plot(x='Generation number', y='Mean',
                          title='Mediana dopasowania osobnika w populacji', grid=True, legend=False)
ax.set_xlabel('Numer pokolenia')
ax.set_ylabel('\n'.join(wrap('Wartość funkcji dopasowania (MSE walidacyjne)', 30)))
plt.savefig('plots\\g_a_mean_fitness.eps')

# %%
ax = spotify_results.plot(x='Generation number', y='Average',
                          title='Średnie dopasowanie osobnika w populacji', grid=True, legend=False)
ax.set_xlabel('Numer pokolenia')
ax.set_ylabel('\n'.join(wrap('Wartość funkcji dopasowania (MSE walidacyjne)', 30)))
plt.savefig('plots\\g_a_average_fitness.eps')

# %%
ax = spotify_results.plot(x='Generation number', y='Standard deviation',
                          title='Odchylenie standardowe dopasowanie osobnika', grid=True, legend=False)
ax.set_xlabel('Numer pokolenia')
ax.set_ylabel('\n'.join(wrap('Odchylenie standardowe funkcji dopasowania', 30)))
plt.savefig('plots\\g_a_fitness_standard_deviation.eps')

# %%
# read in all our data
final_model_results = pd.read_csv("../results/final_model_log_2022-01-15_11-41-09.csv", sep=";")

# %%
# look at a few rows of the results file
final_model_results.sample(5)
# Out:
#     epoch        loss  mean_absolute_error  mean_squared_error       rmse  \
# 27     27  537.632507            19.895689          537.632507  23.186903
# 86     86  107.564079             7.320215          107.564079  10.371310
# 21     21  683.646423            22.396597          683.646423  26.146633
# 74     74  109.638428             7.162241          109.638428  10.470837
# 43     43  274.704071            13.431485          274.704041  16.574198
#
#       val_loss  val_mean_absolute_error  val_mean_squared_error   val_rmse
# 27  489.129700                18.614090              489.129700  22.116276
# 86  107.207558                 7.177708              107.207558  10.354108
# 21  713.362610                22.796131              713.362610  26.708849
# 74  108.536583                 7.059393              108.536583  10.418089
# 43  258.188171                12.467930              258.188171  16.068233

# %%
# get info about DataFrame columns
final_model_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   epoch                    97 non-null     int64
#  1   loss                     97 non-null     float64
#  2   mean_absolute_error      97 non-null     float64
#  3   mean_squared_error       97 non-null     float64
#  4   rmse                     97 non-null     float64
#  5   val_loss                 97 non-null     float64
#  6   val_mean_absolute_error  97 non-null     float64
#  7   val_mean_squared_error   97 non-null     float64
#  8   val_rmse                 97 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 6.9 KB

# %%
ax = final_model_results.plot(x='epoch', y=['mean_absolute_error', 'val_mean_absolute_error'],
                              title='\n'.join(wrap('Porównanie MAE dla zbioru treningowego i walidacyjnego', 40)),
                              grid='True')
ax.set_xlabel('Numer epoki')
ax.set_ylabel('MAE')
ax.legend(['MAE dla zbioru treningowego', 'MEA dla zbioru walidacyjnego'])
plt.savefig('plots\\f_m_mae_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
ax = final_model_results.plot(x='epoch', y=['mean_squared_error', 'val_mean_squared_error'],
                              title='\n'.join(wrap('Porównanie MSE dla zbioru treningowego i walidacyjnego', 40)),
                              grid='True')
ax.set_xlabel('Numer epoki')
ax.set_ylabel('MSE')
ax.legend(['MSE dla zbioru treningowego', 'MSE dla zbioru walidacyjnego'])
plt.savefig('plots\\f_m_mse_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
ax = final_model_results.plot(x='epoch', y=['rmse', 'val_rmse'],
                              title='\n'.join(wrap('Porównanie RMSE dla zbioru treningowego i walidacyjnego', 40)),
                              grid='True')
ax.set_xlabel('Numer epoki')
ax.set_ylabel('RMSE')
ax.legend(['RMSE dla zbioru treningowego', 'RMSE dla zbioru walidacyjnego'])
plt.savefig('plots\\f_m_rmse_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
