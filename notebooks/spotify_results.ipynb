# %%
# modules we'll use
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read in all our data
spotify_results  = pd.read_csv("../results/genetic_algorithm_stats_2022-01-09_22-17-09.csv")

# %%
# look at a few rows of the results file
spotify_results.sample(5)
# Out:
#      Generation number  Best fitness  \
# 193                193    107.646431
# 148                148    107.657249
# 48                  48    107.827736
# 120                120    107.657249
# 68                  68    107.802071
#
#                                            Best genome  Worst fitness  \
# 193  Genome{fitness:107.64643096923828,genes:[Integ...     108.978951
# 148  Genome{fitness:107.6572494506836,genes:[Intege...     111.015633
# 48   Genome{fitness:107.8277359008789,genes:[Intege...     108.806725
# 120  Genome{fitness:107.6572494506836,genes:[Intege...     108.475182
# 68   Genome{fitness:107.80207061767578,genes:[Integ...     108.783485
#
#                                           Worst genome        Mean  \
# 193  Genome{fitness:108.97895050048828,genes:[Integ...  107.990077
# 148  Genome{fitness:111.01563262939453,genes:[Integ...  108.176558
# 48   Genome{fitness:108.80672454833984,genes:[Integ...  108.053588
# ...

# %%
# get info about DataFrame columns
spotify_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Generation number   201 non-null    int64
#  1   Best fitness        201 non-null    float64
#  2   Best genome         201 non-null    object
#  3   Worst fitness       201 non-null    float64
#  4   Worst genome        201 non-null    object
#  5   Mean                201 non-null    float64
#  6   Average             201 non-null    float64
#  7   Standard deviation  201 non-null    float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 12.7+ KB

# %%
spotify_results.plot(x="Generation number", y="Best fitness")
plt.savefig('plots\\g_a_best_fitness.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
spotify_results.plot(x="Generation number", y="Worst fitness")
plt.savefig('plots\\g_a_worst_fitness.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
spotify_results.plot(x="Generation number", y="Mean")
plt.savefig('plots\\g_a_mean_fitness.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
spotify_results.plot(x="Generation number", y="Average")
plt.savefig('plots\\g_a_average_fitness.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
spotify_results.plot(x="Generation number", y="Standard deviation")
plt.savefig('plots\\g_a_fitness_standard_deviation.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# read in all our data
final_model_results  = pd.read_csv("../results/final_model_log_2022-01-12_15-04-21.csv", sep=";")

# %%
# look at a few rows of the results file
final_model_results.sample(5)
# Out:
#     epoch        loss  mean_absolute_error  mean_squared_error       rmse  \
# 50     50  198.353226            10.631935          198.353226  14.083793
# 65     65  122.244125             7.535137          122.244125  11.056406
# 46     46  232.986786            11.958078          232.986786  15.263905
# 20     20  696.947021            22.604393          696.947021  26.399754
# 28     28  502.693024            19.189131          502.693024  22.420816
#
#       val_loss  val_mean_absolute_error  val_mean_squared_error   val_rmse
# 50  198.276642                10.670850              198.276642  14.081074
# 65  121.675354                 7.483006              121.675354  11.030655
# 46  211.152847                11.117043              211.152847  14.531099
# 20  690.659119                22.533060              690.659119  26.280394
# 28  511.960693                19.348135              511.960693  22.626549

# %%
# get info about DataFrame columns
final_model_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   epoch                    100 non-null    int64
#  1   loss                     100 non-null    float64
#  2   mean_absolute_error      100 non-null    float64
#  3   mean_squared_error       100 non-null    float64
#  4   rmse                     100 non-null    float64
#  5   val_loss                 100 non-null    float64
#  6   val_mean_absolute_error  100 non-null    float64
#  7   val_mean_squared_error   100 non-null    float64
#  8   val_rmse                 100 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 7.2 KB

# %%
final_model_results.plot(x='epoch', y=['mean_absolute_error', 'val_mean_absolute_error'])
plt.savefig('plots\\f_m_mae_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
final_model_results.plot(x='epoch', y=['mean_squared_error', 'val_mean_squared_error'])
plt.savefig('plots\\f_m_mse_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
final_model_results.plot(x='epoch', y=['rmse', 'val_rmse'])
plt.savefig('plots\\f_m_rmse_train_valid.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
